# %%
# !sudo chown $USER:$USER *
# !sudo usermod -a -G docker $USER

# %%
# !docker build -t myimg .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 203B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:latest           0.2s
# [+] Building 0.3s (2/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 203B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:latest           0.3s
# [+] Building 0.5s (4/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 203B                                       0.0s
# ...

# %%
# !docker images
# Out:
# REPOSITORY   TAG       IMAGE ID       CREATED          SIZE
# myimg        latest    8a8d78ef3746   15 seconds ago   1.13GB

# %%
# !aws ecr get-login-password --region ap-south-1 | docker login --username AWS --password-stdin 993726038949.dkr.ecr.ap-south-1.amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
# !docker build -t offline12ecr .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 203B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:latest           0.2s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 203B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:latest           0.3s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 203B                                       0.0s
# ...

# %%
# !docker tag offline12ecr:latest 993726038949.dkr.ecr.ap-south-1.amazonaws.com/offline12ecr:latest

# %%
# !docker push 993726038949.dkr.ecr.ap-south-1.amazonaws.com/offline12ecr:latest
# Out:
# The push refers to repository [993726038949.dkr.ecr.ap-south-1.amazonaws.com/offline12ecr]
#
# 8e220f87: Preparing
# 0c44cf9c: Preparing
# 82519e41: Preparing
# f50b46d0: Preparing
# bf087553: Preparing
# 499dfbe1: Preparing
# 30456c98: Preparing
# 35c5db2d: Preparing
# fecc5540: Preparing
# latest: digest: sha256:2cc3ff4e541a5beb4b5af273bba53e5aebe3a7c9695fe2ee73151e6db3c852a0 size: 2423

# %%
# !docker images
# Out:
# REPOSITORY                                                   TAG       IMAGE ID       CREATED              SIZE
# 993726038949.dkr.ecr.ap-south-1.amazonaws.com/offline12ecr   latest    e7207a92ec16   About a minute ago   1.13GB
# offline12ecr                                                 latest    e7207a92ec16   About a minute ago   1.13GB
# myimg                                                        latest    8a8d78ef3746   3 minutes ago        1.13GB
